# %% [markdown]
# ### Importing libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Loading Dataset

# %%
data = pd.read_csv('attrition.csv') #Import Dataset

# %%
data.head()
# Out:
#    Age  Attrition     BusinessTravel              Department EducationField  \
# 0   41          1      Travel_Rarely                   Sales  Life Sciences
# 1   49          0  Travel_Frequently  Research & Development  Life Sciences
# 2   37          1      Travel_Rarely  Research & Development          Other
# 3   33          0  Travel_Frequently  Research & Development  Life Sciences
# 4   27          0      Travel_Rarely  Research & Development        Medical
#
#    EnvironmentSatisfaction  Gender  JobInvolvement  JobLevel  JobSatisfaction  \
# 0                        2  Female               3         2                4
# 1                        3    Male               2         2                2
# 2                        4    Male               2         1                3
# 3                        4  Female               3         1                3
# 4                        1    Male               3         1                2
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 20 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Age                      1470 non-null   int64
#  1   Attrition                1470 non-null   int64
#  2   BusinessTravel           1470 non-null   object
#  3   Department               1470 non-null   object
#  4   EducationField           1470 non-null   object
#  5   EnvironmentSatisfaction  1470 non-null   int64
#  6   Gender                   1470 non-null   object
#  7   JobInvolvement           1470 non-null   int64
#  8   JobLevel                 1470 non-null   int64
#  9   JobSatisfaction          1470 non-null   int64
#  10  MaritalStatus            1470 non-null   object
#  11  MonthlyIncome            1470 non-null   int64
#  12  OverTime                 1470 non-null   object
#  13  TotalWorkingYears        1470 non-null   int64
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
#define categorical columns
cat_cols = list(data.select_dtypes('object'))
cat_cols
# Out:
# ['BusinessTravel',
#  'Department',
#  'EducationField',
#  'Gender',
#  'MaritalStatus',
#  'OverTime']

# %%
data.Age.describe()
# Out:
# count    1470.000000
# mean       36.923810
# std         9.135373
# min        18.000000
# 25%        30.000000
# 50%        36.000000
# 75%        43.000000
# max        60.000000
# Name: Age, dtype: float64

# %%
data.hist(column = "Age", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 14)
plt.ylabel("count", fontsize = 12)
plt.xlabel("Employees", fontsize = 12)
plt.title("Histogram of Age", fontsize = 16)
plt.savefig('histogram.jpeg')

# %%
data.boxplot(column="Age", grid = False, figsize = (8,6), vert = False)
plt.xlabel("Age of People")
plt.title("Boxplot of Age")
plt.show()

# %% [markdown]
# Under our analysis, we have found that
#
# - The average number of employees give or take that are working or have worked in the company are about 36 years old.
# - The youngest employee working in the company is 18 years old while the oldest employee is 60 years old.
# - 25% of the employees that are working or have worked in the company have age less than 30 years and on the other hand 25% employees have age more than 43 years.
# - 50% of the employess working in the company or have worked in the company have age between 30 and 43 years.

# %%
data.Attrition.value_counts()
# Out:
# 0    1233
# 1     237
# Name: Attrition, dtype: int64

# %%
data.Attrition.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12)
plt.ylabel("Frequencies of Attrition")
plt.xticks(rotation=False)
plt.title("Barplot for Attrition")
plt.show()

# %% [markdown]
# Under our analysis of the company, we have found that there are 237 employees who have left the company and 1233 employees are still working in the company.

# %%
data.BusinessTravel.value_counts()/len(data)*100
# Out:
# Travel_Rarely        70.952381
# Travel_Frequently    18.843537
# Non-Travel           10.204082
# Name: BusinessTravel, dtype: float64

# %%
data.BusinessTravel.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12, rot = 45)
plt.ylabel("Frequencies of Business Travels")
plt.title("Barplot for Business Travels")
plt.show()

# %% [markdown]
# We have found that out of those employees that are working or those who have left the company, around 71% employees traveled rarely, 19% employees traveled frequently and 10% employees did not travel at all for business purposes.

# %%
data.Department.value_counts()
# Out:
# Research & Development    961
# Sales                     446
# Human Resources            63
# Name: Department, dtype: int64

# %%
data.Department.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12, rot = 45)
plt.ylabel("Frequencies of Department")
plt.title("Barplot for Department")
plt.show()

# %% [markdown]
# We have found that, out of the employees that are working or those who had worked in the company
#
# - 961 employees are in Research & Development
# - 446 employees are in Sales Department
# - 63 employees are in HUman Resources

# %%
data.EducationField.value_counts()/len(data)*100
# Out:
# Life Sciences       41.224490
# Medical             31.564626
# Marketing           10.816327
# Technical Degree     8.979592
# Other                5.578231
# Human Resources      1.836735
# Name: EducationField, dtype: float64

# %%
data.EducationField.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12, rot = 45)
plt.ylabel('Frequencies of Education Field')
plt.title('Barplot of Education Field')
plt.show()

# %% [markdown]
# Under our analysis, out of the employees that are working or have worked in the company belonged to the following educational fields
#
# - 606 employees are from Life Sciences
# - 464 employees are from Medical field
# - 159 employees are from Marketing field
# - 132 employees have Technical Degree
# - 27 employees are from Human Resources and 82 employees belonged to other educational fields

# %%
data.EnvironmentSatisfaction.value_counts()
# Out:
# 3    453
# 4    446
# 2    287
# 1    284
# Name: EnvironmentSatisfaction, dtype: int64

# %%
data.EnvironmentSatisfaction.value_counts().plot(kind = 'bar', figsize =(6,6), color = 'olive', fontsize = 12 ,rot = 0)
plt.ylabel('Frequencies of Environment Satisfaction')
plt.title('Barplot of Environment Satisfaction')
plt.show()

# %% [markdown]
# We found that the rating scale of Environment Satisfaction for employees that are working or have left the company, maximum number of employees have rated the environment 3 while about 280 employees have rated the working environment as 1.

# %%
data.Gender.value_counts()/len(data)*100
# Out:
# Male      60.0
# Female    40.0
# Name: Gender, dtype: float64

# %%
data.Gender.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12,rot = 0)
plt.ylabel('Frequencies of Gender')
plt.title('Barplot of Gender')
plt.show()

# %% [markdown]
# We have found that out the the employees that are working or have worked in the company, 588 employees are Female and on the other hand Male employees are 882.

# %%
data.JobInvolvement.value_counts()
# Out:
# 3    868
# 2    375
# 4    144
# 1     83
# Name: JobInvolvement, dtype: int64

# %%
Under our analysis we have found that 868 employees

# %%
data.JobInvolvement.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12,rot = 0)
plt.ylabel('Frequencies of Job Involvement')
plt.title('Barplot of Job Involvement')
plt.show()

# %%
data.JobLevel.value_counts()/len(data)*100
# Out:
# 1    36.938776
# 2    36.326531
# 3    14.829932
# 4     7.210884
# 5     4.693878
# Name: JobLevel, dtype: float64

# %%
data.JobLevel.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12,rot = 0)
plt.ylabel('Frequencies of Job Level')
plt.title('Barplot of Job Level')
plt.show()

# %% [markdown]
# Under our analysis, we have found that out of the employees that are working or have worked in the company
#
# - near about 540 employees are working have Job Level 1 and Job Level 2
# - 218 employees have Job Level 3
# - about 100 empoyees have Job Level 4
# - and around 70 employees have the highest Job Level that is 5.

# %%
data.JobSatisfaction.value_counts()/len(data)*100
# Out:
# 4    31.224490
# 3    30.068027
# 1    19.659864
# 2    19.047619
# Name: JobSatisfaction, dtype: float64

# %%
data.JobSatisfaction.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12,rot = 0)
plt.ylabel('Frequencies of Job Satisfaction')
plt.title('Barplot of Job Satisfaction')
plt.show()

# %% [markdown]
# We found that out of the employees that are working or have worked, the Job Satisfaction given by them on a scale of 1-4 is that
#
# - about 460 employees have the maximum level of Job Satisfaction
# - near about 440 employees have rated as 3
# - 280 employees have rated as 2 and are not very satisfied with their job.
# - and around 290 employees have rated lowest level of Job Satisfaction.

# %%
data.MaritalStatus.value_counts()/len(data)*100
# Out:
# Married     45.782313
# Single      31.972789
# Divorced    22.244898
# Name: MaritalStatus, dtype: float64

# %%
data.MaritalStatus.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12,rot = 0)
plt.ylabel('Frequencies of Marital Status')
plt.title('Barplot of Marital Status')
plt.show()

# %% [markdown]
# Under our analysis, out of the employees that are working or have worked in the company
# - about 670 employees are Married
# - 470 employees are Single
# - and 327 employees are Divorced

# %%
data.OverTime.value_counts()/len(data)*100
# Out:
# No     71.70068
# Yes    28.29932
# Name: OverTime, dtype: float64

# %%
data.OverTime.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12,rot = 0)
plt.ylabel('Frequencies of Over Time')
plt.title('Barplot of Over Time')
plt.show()

# %%
data.OverTime.value_counts()/len(data)*100
# Out:
# No     71.70068
# Yes    28.29932
# Name: OverTime, dtype: float64

# %%
data.OverTime.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12, rot = 0)
plt.ylabel("Frequencies of Overtime")
plt.title("Barplot for Overtime")
plt.show()

# %% [markdown]
# Under our analysis, we found that around 1050 employees did Overtime and on the other hand near about 420 employees didn't do Overtime.

# %%
(data.WorkLifeBalance.value_counts()/len(data))*100
# Out:
# 3    60.748299
# 2    23.401361
# 4    10.408163
# 1     5.442177
# Name: WorkLifeBalance, dtype: float64

# %% [markdown]
# Under our analysis, out of the employees that are working or have worked in the company
# we have found that around 61% employees have rated 3,3% employees rated 2,  10% employees rated 4
# 5% employees rated 1 to the work life balance.

# %%
data.WorkLifeBalance.value_counts().plot(kind = 'bar', figsize = (6,6), color = 'olive', fontsize = 12,rot = 0)
plt.ylabel('Frequencies of Work Life Balance')
plt.title('Barplot of Work Life Balance')
plt.show()

# %%
data.MonthlyIncome.describe()
# Out:
# count     1470.000000
# mean      6502.931293
# std       4707.956783
# min       1009.000000
# 25%       2911.000000
# 50%       4919.000000
# 75%       8379.000000
# max      19999.000000
# Name: MonthlyIncome, dtype: float64

# %%
data.hist(column = "MonthlyIncome", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black')
plt.xlabel("Monthly Income", fontsize = 12)
plt.title("Histogram of MonthlyIncome", fontsize = 16)
plt.show()

# %%
data.boxplot(column="MonthlyIncome", grid = False, figsize = (12,6), vert = False)
plt.xlabel("Monthly Income of People")
plt.title("Boxplot of Monthly Income")
plt.show()

# %% [markdown]
# Under our analysis, out of the employees that are working or have worked in the company
#
# - the average monthly income give or take for employees is found out to be 6500.
# - the minimum monthly income for an employee is 1000.
# - the maximum monthli income for an employee is around 20000.
# - 25% of the employees have monthly income less than 3000.
# - 50% of the employees have monthly income between 2900 and 8400
# - and 75% of the employees have monthly income less than 8400.

# %%
data.TotalWorkingYears.describe()
# Out:
# count    1470.000000
# mean       11.279592
# std         7.780782
# min         0.000000
# 25%         6.000000
# 50%        10.000000
# 75%        15.000000
# max        40.000000
# Name: TotalWorkingYears, dtype: float64

# %%
data.hist(column = "TotalWorkingYears", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black')
plt.xlabel("Total Working Years", fontsize = 12)
plt.title("Histogram of Total Working Years", fontsize = 16)
plt.show()

# %%
data.boxplot(column="TotalWorkingYears", grid = False, figsize = (8,6), vert = False)
plt.xlabel("Total Working Years")
plt.title("Boxplot of Total Working Years")
plt.show()

# %% [markdown]
# Out of the employees that are working or have worked in the company, we have found that
#
# -

# %%
data.YearsAtCompany.describe()
# Out:
# count    1470.000000
# mean        7.008163
# std         6.126525
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         9.000000
# max        40.000000
# Name: YearsAtCompany, dtype: float64

# %%
data.hist(column = "YearsAtCompany", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black')
plt.xlabel("Years At Company", fontsize = 12)
plt.title("Histogram of Years At Company", fontsize = 16)
plt.show()

# %%
data.boxplot(column="YearsAtCompany", grid = False, figsize = (12,6), vert = False)
plt.xlabel("Years At Company")
plt.title("Boxplot of Years At Company")
plt.show()

# %% [markdown]
# Under our analaysis, out of the employees that are working or have worked in the company
#
# - at an average give or take employees have worked for 7 years in the company
# - the minimum duration of year that an employee has worked in the company is 0
# - 25% of employees have worked for 3 or less than 3 years
# - 50% of employees have worked between 3 to 9 years
# - 75% of employees have worked for less than 9 years
# - and the maximum duration an employee has worked for the company is 40 years.

# %%
data.YearsInCurrentRole.describe()
# Out:
# count    1470.000000
# mean        4.229252
# std         3.623137
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        18.000000
# Name: YearsInCurrentRole, dtype: float64

# %%
data.hist(column = "YearsInCurrentRole", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black')
plt.xlabel("Years In Current Role", fontsize = 12)
plt.title("Histogram of Years In Current Role", fontsize = 16)
plt.show()

# %%
data.boxplot(column="YearsInCurrentRole", grid = False, figsize = (8,6), vert = False)
plt.xlabel("Years In Current Role")
plt.title("Boxplot of Years In Current Role")
plt.show()

# %%
data.YearsSinceLastPromotion.describe()
# Out:
# count    1470.000000
# mean        2.187755
# std         3.222430
# min         0.000000
# 25%         0.000000
# 50%         1.000000
# 75%         3.000000
# max        15.000000
# Name: YearsSinceLastPromotion, dtype: float64

# %%
data.hist(column = "YearsSinceLastPromotion", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 14)
plt.xlabel("Years Since Last Promotion", fontsize = 12)
plt.title("Histogram of Years Since Last Promotion", fontsize = 16)
plt.show()

# %%
data.boxplot(column="YearsSinceLastPromotion", grid = False, figsize = (8,6), vert = False)
plt.xlabel("Years Since Last Promotion")
plt.title("Boxplot of Years Since Last Promotion")
plt.show()

# %%
data.YearsWithCurrManager.describe()
# Out:
# count    1470.000000
# mean        4.123129
# std         3.568136
# min         0.000000
# 25%         2.000000
# 50%         3.000000
# 75%         7.000000
# max        17.000000
# Name: YearsWithCurrManager, dtype: float64

# %%
data.hist(column = "YearsWithCurrManager", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black')
plt.xlabel("Years With Curr Manager", fontsize = 12)
plt.title("Histogram of Years With Curr Manager", fontsize = 16)
plt.show()

# %%
data.boxplot(column="YearsWithCurrManager", grid = False, figsize = (8,6), vert = False)
plt.xlabel("Years With Curr Manager")
plt.title("Boxplot of Years With Curr Manager")
plt.show()

# %%
data.DistanceFromHome.describe()
# Out:
# count    1470.000000
# mean        9.192517
# std         8.106864
# min         1.000000
# 25%         2.000000
# 50%         7.000000
# 75%        14.000000
# max        29.000000
# Name: DistanceFromHome, dtype: float64

# %%
data.hist(column = "DistanceFromHome", grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black')
plt.xlabel("Distance From Home", fontsize = 12)
plt.title("Histogram of Distance From Home", fontsize = 16)
plt.show()

# %%
data.boxplot(column="DistanceFromHome", grid = False, figsize = (8,6), vert = False)
plt.xlabel("Distance From Home")
plt.title("Boxplot of Distance From Home")
plt.show()

# %% [markdown]
# **Bivariate Analysis**

# %%
data[['Attrition','MonthlyIncome']].groupby(['Attrition']).describe()
# Out:
#           MonthlyIncome                                                    \
#                   count         mean          std     min     25%     50%
# Attrition
# 0                1233.0  6832.739659  4818.208001  1051.0  3211.0  5204.0
# 1                 237.0  4787.092827  3640.210367  1009.0  2373.0  3202.0
#
#
#               75%      max
# Attrition
# 0          8834.0  19999.0
# 1          5916.0  19859.0

# %% [markdown]
# Under our analysis, we have found that
# - among the employees that have left the company, the average monthly income give or take is near around 4800 while the employees that are still working in the company, the average monthly income give or take is about 6800.
# - the minimum monthly income of an employee who has left the company is 1009 on the other hand it is 1051 for an employee who is still in the company.
# - 25% of the employees that have left the company have monthly income less than 2400 while 25% of the employees that are still working in the company have monthly income less than 3200.
# - 50% of the employees that have left the company have monthly income between 2300 and 3200 while 50% of the employees that are working in the company have monthly income between 3200 and 5200.
# - 25% of the emplyees that have left the company have monthly income more than 5900 on the other hand 75% of the employees that are working in the company haave monthly income more than 8800.
# - the maximum monthly income for the employees who have left and for the employees who are still working in the company is near about 20000.

# %%
data_nocat = data.drop(data[['Attrition','BusinessTravel','Department','EducationField','EnvironmentSatisfaction','Gender','JobInvolvement','JobLevel','JobSatisfaction','MaritalStatus','OverTime','WorkLifeBalance']], axis=1)

# %%
corrM = data_nocat.corr()
corrM
# Out:
#                               Age  MonthlyIncome  TotalWorkingYears  \
# Age                      1.000000       0.497855           0.680381
# MonthlyIncome            0.497855       1.000000           0.772893
# TotalWorkingYears        0.680381       0.772893           1.000000
# YearsAtCompany           0.311309       0.514285           0.628133
# YearsInCurrentRole       0.212901       0.363818           0.460365
# YearsSinceLastPromotion  0.216513       0.344978           0.404858
# YearsWithCurrManager     0.202089       0.344079           0.459188
# DistanceFromHome        -0.001686      -0.017014           0.004628
#
#                          YearsAtCompany  YearsInCurrentRole  \
# Age                            0.311309            0.212901
# MonthlyIncome                  0.514285            0.363818
# TotalWorkingYears              0.628133            0.460365
# YearsAtCompany                 1.000000            0.758754
# ...

# %%
from pandas.plotting import scatter_matrix
scatter_matrix(data_nocat, alpha = 0.5,
              figsize = (30,15),
              diagonal='hist')
plt.show()

# %%
import seaborn as sns
mask = np.triu(np.ones_like(data_nocat.corr()))
# create colormap
colormap = sns.color_palette("Blues")

plt.figure(figsize=(16,8))
plt.title('Correlation between All Numerical Feature', size=15)
sns.heatmap(data_nocat.corr(), annot=True, cmap=colormap)

plt.show()

# %%
import seaborn as sns
mask = np.triu(np.ones_like(data_nocat.corr()))
# create colormap
colormap = sns.color_palette("Blues")

plt.figure(figsize=(16,8))
plt.title('Correlation between All Numerical Feature', size=15)
sns.heatmap(data.corr(), annot=True, cmap=colormap)

plt.show()

# %%
data[['Age','Attrition']].groupby(['Attrition']).describe()
# Out:
#               Age
#             count       mean      std   min   25%   50%   75%   max
# Attrition
# 0          1233.0  37.561233  8.88836  18.0  31.0  36.0  43.0  60.0
# 1           237.0  33.607595  9.68935  18.0  28.0  32.0  39.0  58.0

# %%
data.hist(column = "Age", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 7)
plt.xlabel("Age", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="Age", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Age of People")
plt.title("Boxplot of Age by Attrition")
plt.show()

# %% [markdown]
# Under our analysis, we found that
# - the average age give or take of the employees who left the company is 33 years while the employees who are still working in the company is 37 years.
# - the youngest employee who has left the company and the youngest employee who is still working in the company is 18 years.
# - 25% of the employees who have left the company are less than 28 years old while 25% of the employees who are still in the company are less than 31 years old.
# - 50% of the employees who have left the company are between 28 and 32 years while 50% of the employees who are still in the company are between 31 and 36 years.
# - 75% of the employees who have left the company are less than 39 years old while 75% of the employees who are still in the company are less than 43 years old.
# - the oldest employee whos has left the company is 58 years old while the oldest employee who is still working in the company is 60 years old.

# %%
bt_table = pd.crosstab(data.BusinessTravel,columns=data.Attrition)
bt_table
# Out:
# Attrition            0    1
# BusinessTravel
# Non-Travel         138   12
# Travel_Frequently  208   69
# Travel_Rarely      887  156

# %%
bt_row = bt_table.sum(axis = 1)
bt_row
# Out:
# BusinessTravel
# Non-Travel            150
# Travel_Frequently     277
# Travel_Rarely        1043
# dtype: int64

# %%
bt_table.div(bt_row,axis = 0)
# Out:
# Attrition                 0         1
# BusinessTravel
# Non-Travel         0.920000  0.080000
# Travel_Frequently  0.750903  0.249097
# Travel_Rarely      0.850431  0.149569

# %%
bt_table.plot(kind = 'bar', rot = 0, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
dept_table = pd.crosstab(data.Department,columns=data.Attrition)
dept_table
# Out:
# Attrition                 0    1
# Department
# Human Resources          51   12
# Research & Development  828  133
# Sales                   354   92

# %%
dept_row = dept_table.sum(axis=1)
dept_row
# Out:
# Department
# Human Resources            63
# Research & Development    961
# Sales                     446
# dtype: int64

# %%
dept_table.div(dept_row,axis=0)
# Out:
# Attrition                      0         1
# Department
# Human Resources         0.809524  0.190476
# Research & Development  0.861602  0.138398
# Sales                   0.793722  0.206278

# %%
dept_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
ef_table = pd.crosstab(data.EducationField,columns=data.Attrition)
ef_table
# Out:
# Attrition           0   1
# EducationField
# Human Resources    20   7
# Life Sciences     517  89
# Marketing         124  35
# Medical           401  63
# Other              71  11
# Technical Degree  100  32

# %%
ef_row = ef_table.sum(axis=1)

# %%
ef_table.div(ef_row,axis=0)
# Out:
# Attrition                0         1
# EducationField
# Human Resources   0.740741  0.259259
# Life Sciences     0.853135  0.146865
# Marketing         0.779874  0.220126
# Medical           0.864224  0.135776
# Other             0.865854  0.134146
# Technical Degree  0.757576  0.242424

# %%
ef_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
es_table = pd.crosstab(data.EnvironmentSatisfaction,columns=data.Attrition)
es_table
# Out:
# Attrition                  0   1
# EnvironmentSatisfaction
# 1                        212  72
# 2                        244  43
# 3                        391  62
# 4                        386  60

# %%
es_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
sns.countplot(data=data,x= "EnvironmentSatisfaction",hue="Attrition")
# Out:
# <AxesSubplot:xlabel='EnvironmentSatisfaction', ylabel='count'>

# %%
gen_table= pd.crosstab(data.Gender, columns=data.Attrition)
gen_table
# Out:
# Attrition    0    1
# Gender
# Female     501   87
# Male       732  150

# %%
sns.countplot(data=data,x= "Gender",hue="Attrition")
# Out:
# <AxesSubplot:xlabel='Gender', ylabel='count'>

# %%
ji_table= pd.crosstab(data.JobInvolvement, columns=data.Attrition)
ji_table
# Out:
# Attrition         0    1
# JobInvolvement
# 1                55   28
# 2               304   71
# 3               743  125
# 4               131   13

# %%
ji_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
jl_table= pd.crosstab(data.JobLevel, columns=data.Attrition)
jl_table
# Out:
# Attrition    0    1
# JobLevel
# 1          400  143
# 2          482   52
# 3          186   32
# 4          101    5
# 5           64    5

# %%
jl_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
js_table= pd.crosstab(data.JobSatisfaction, columns=data.Attrition)
js_table
# Out:
# Attrition          0   1
# JobSatisfaction
# 1                223  66
# 2                234  46
# 3                369  73
# 4                407  52

# %%
js_row = js_table.sum(axis=1)
js_row
# Out:
# JobSatisfaction
# 1    289
# 2    280
# 3    442
# 4    459
# dtype: int64

# %%
js_table.div(js_row,axis=0)
# Out:
# Attrition               0         1
# JobSatisfaction
# 1                0.771626  0.228374
# 2                0.835714  0.164286
# 3                0.834842  0.165158
# 4                0.886710  0.113290

# %%
js_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
ms_table= pd.crosstab(data.MaritalStatus, columns=data.Attrition)
ms_table
# Out:
# Attrition        0    1
# MaritalStatus
# Divorced       294   33
# Married        589   84
# Single         350  120

# %%
ms_row = ms_table.sum(axis=1)
ms_row
# Out:
# MaritalStatus
# Divorced    327
# Married     673
# Single      470
# dtype: int64

# %%
ms_table.div(ms_row,axis=0)
# Out:
# Attrition             0         1
# MaritalStatus
# Divorced       0.899083  0.100917
# Married        0.875186  0.124814
# Single         0.744681  0.255319

# %%
ms_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
data[['MonthlyIncome','Attrition']].groupby(['Attrition']).describe()
# Out:
#           MonthlyIncome                                                    \
#                   count         mean          std     min     25%     50%
# Attrition
# 0                1233.0  6832.739659  4818.208001  1051.0  3211.0  5204.0
# 1                 237.0  4787.092827  3640.210367  1009.0  2373.0  3202.0
#
#
#               75%      max
# Attrition
# 0          8834.0  19999.0
# 1          5916.0  19859.0

# %%
data.hist(column = "MonthlyIncome", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 7)
plt.xlabel("Monthly Income of People", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="MonthlyIncome", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Monthly Income of People")
plt.title("Boxplot of Monthly Income of People by Attrition")
plt.show()

# %%
ot_table= pd.crosstab(data.OverTime, columns=data.Attrition)
ot_table
# Out:
# Attrition    0    1
# OverTime
# No         944  110
# Yes        289  127

# %%
ot_row = ot_table.sum(axis=1)
ot_row
# Out:
# OverTime
# No     1054
# Yes     416
# dtype: int64

# %%
ot_table.div(ot_row,axis=0)
# Out:
# Attrition         0         1
# OverTime
# No         0.895636  0.104364
# Yes        0.694712  0.305288

# %%
jl_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
data[['TotalWorkingYears','Attrition']].groupby(['Attrition']).describe()
# Out:
#           TotalWorkingYears
#                       count       mean       std  min  25%   50%   75%   max
# Attrition
# 0                    1233.0  11.862936  7.760719  0.0  6.0  10.0  16.0  38.0
# 1                     237.0   8.244726  7.169204  0.0  3.0   7.0  10.0  40.0

# %%
data.hist(column = "TotalWorkingYears", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 10)
plt.xlabel("Total Working Years", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="TotalWorkingYears", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Total Working Years")
plt.title("Boxplot of Total Working Years by Attrition")
plt.show()

# %%
wlb_table= pd.crosstab(data.WorkLifeBalance, columns=data.Attrition)
wlb_table
# Out:
# Attrition          0    1
# WorkLifeBalance
# 1                 55   25
# 2                286   58
# 3                766  127
# 4                126   27

# %%
wlb_row = wlb_table.sum(axis=1)
wlb_row
# Out:
# WorkLifeBalance
# 1     80
# 2    344
# 3    893
# 4    153
# dtype: int64

# %%
wlb_table.div(wlb_row,axis =0)
# Out:
# Attrition               0         1
# WorkLifeBalance
# 1                0.687500  0.312500
# 2                0.831395  0.168605
# 3                0.857783  0.142217
# 4                0.823529  0.176471

# %%
wlb_table.plot(kind = 'bar', rot = 45, figsize = (10,6), color = ['cadetblue','sandybrown'], fontsize = 12)
plt.show()

# %%
data[['YearsAtCompany','Attrition']].groupby(['Attrition']).describe()
# Out:
#           YearsAtCompany
#                    count      mean       std  min  25%  50%   75%   max
# Attrition
# 0                 1233.0  7.369019  6.096298  0.0  3.0  6.0  10.0  37.0
# 1                  237.0  5.130802  5.949984  0.0  1.0  3.0   7.0  40.0

# %%
data.hist(column = "YearsAtCompany", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 10)
plt.xlabel("Years at Company", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="YearsAtCompany", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Years at Company")
plt.title("Boxplot of Years at Company by Attrition")
plt.show()

# %%
data[['YearsInCurrentRole','Attrition']].groupby(['Attrition']).describe()
# Out:
#           YearsInCurrentRole
#                        count      mean       std  min  25%  50%  75%   max
# Attrition
# 0                     1233.0  4.484185  3.649402  0.0  2.0  3.0  7.0  18.0
# 1                      237.0  2.902954  3.174827  0.0  0.0  2.0  4.0  15.0

# %%
data.hist(column = "YearsInCurrentRole", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 7)
plt.xlabel("Years In Current Role", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="YearsInCurrentRole", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Years In Current Role")
plt.title("Boxplot of Years In Current Role by Attrition")
plt.show()

# %%
data[['YearsSinceLastPromotion','Attrition']].groupby(['Attrition']).describe()
# Out:
#           YearsSinceLastPromotion                                          \
#                             count      mean       std  min  25%  50%  75%
# Attrition
# 0                          1233.0  2.234388  3.234762  0.0  0.0  1.0  3.0
# 1                           237.0  1.945148  3.153077  0.0  0.0  1.0  2.0
#
#
#             max
# Attrition
# 0          15.0
# 1          15.0

# %%
data.hist(column = "YearsSinceLastPromotion", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 7)
plt.xlabel("Years Since Last Promotion", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="YearsSinceLastPromotion", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Years Since Last Promotion")
plt.title("Boxplot of Years Since Last Promotion by Attrition")
plt.show()

# %%
data[['YearsWithCurrManager','Attrition']].groupby(['Attrition']).describe()
# Out:
#           YearsWithCurrManager
#                          count      mean       std  min  25%  50%  75%   max
# Attrition
# 0                       1233.0  4.367397  3.594116  0.0  2.0  3.0  7.0  17.0
# 1                        237.0  2.852321  3.143349  0.0  0.0  2.0  5.0  14.0

# %%
data.hist(column = "YearsWithCurrManager", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 7)
plt.xlabel("Years With Current Manager", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="YearsWithCurrManager", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Years With Current Manager")
plt.title("Boxplot of Years With Current Manager by Attrition")
plt.show()

# %%
data[['DistanceFromHome','Attrition']].groupby(['Attrition']).describe()
# Out:
#           DistanceFromHome
#                      count       mean       std  min  25%  50%   75%   max
# Attrition
# 0                   1233.0   8.915653  8.012633  1.0  2.0  7.0  13.0  29.0
# 1                    237.0  10.632911  8.452525  1.0  3.0  9.0  17.0  29.0

# %%
data.hist(column = "DistanceFromHome", by = 'Attrition', grid = False,figsize = (10,7),color = 'silver', edgecolor = 'black', bins = 7)
plt.xlabel("Distance From Home", fontsize = 12)
plt.ylabel('Number of People')
plt.show()

# %%
data.boxplot(column="DistanceFromHome", by = "Attrition", grid = False, figsize = (8,6), notch = True, rot = 15)
plt.xlabel("Distance From Home")
plt.title("Boxplot of Distance From Home by Attrition")
plt.show()

# %% [markdown]
# # Trivariate Analysis

# %%
corrM
# Out:
#                               Age  MonthlyIncome  TotalWorkingYears  \
# Age                      1.000000       0.497855           0.680381
# MonthlyIncome            0.497855       1.000000           0.772893
# TotalWorkingYears        0.680381       0.772893           1.000000
# YearsAtCompany           0.311309       0.514285           0.628133
# YearsInCurrentRole       0.212901       0.363818           0.460365
# YearsSinceLastPromotion  0.216513       0.344978           0.404858
# YearsWithCurrManager     0.202089       0.344079           0.459188
# DistanceFromHome        -0.001686      -0.017014           0.004628
#
#                          YearsAtCompany  YearsInCurrentRole  \
# Age                            0.311309            0.212901
# MonthlyIncome                  0.514285            0.363818
# TotalWorkingYears              0.628133            0.460365
# YearsAtCompany                 1.000000            0.758754
# ...

# %%
data_1[['JobLevel','Age']].groupby(['JobLevel']).describe()
# Out:
#             Age
#           count       mean       std   min    25%   50%    75%   max
# JobLevel
# 1         143.0  30.195804  8.604993  18.0  24.50  29.0  33.00  58.0
# 2          52.0  35.923077  7.671813  22.0  31.00  34.5  39.25  55.0
# 3          32.0  40.781250  9.328190  28.0  32.75  38.5  48.25  58.0
# 4           5.0  44.600000  6.580274  39.0  40.00  42.0  47.00  55.0
# 5           5.0  50.200000  7.049823  41.0  45.00  52.0  55.00  58.0

# %%
att_1 = data[['EnvironmentSatisfaction','Attrition','TotalWorkingYears']]['Attrition'==1]

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'EducationField',
#        'EnvironmentSatisfaction', 'Gender', 'JobInvolvement', 'JobLevel',
#        'JobSatisfaction', 'MaritalStatus', 'MonthlyIncome', 'OverTime',
#        'TotalWorkingYears', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion', 'YearsWithCurrManager',
#        'DistanceFromHome'],
#       dtype='object')

# %%
data_1 = data.copy
data_1 = data[data['Attrition']==1]
data_1
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      41          1      Travel_Rarely                   Sales
# 2      37          1      Travel_Rarely  Research & Development
# 14     28          1      Travel_Rarely  Research & Development
# 21     36          1      Travel_Rarely                   Sales
# 24     34          1      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 1438   23          1  Travel_Frequently                   Sales
# 1442   29          1      Travel_Rarely  Research & Development
# 1444   56          1      Travel_Rarely  Research & Development
# 1452   50          1  Travel_Frequently                   Sales
# 1461   50          1      Travel_Rarely                   Sales
#
#         EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0        Life Sciences                        2  Female               3
# ...

# %%
data
# Out:
#       Age  Attrition     BusinessTravel              Department  \
# 0      41          1      Travel_Rarely                   Sales
# 1      49          0  Travel_Frequently  Research & Development
# 2      37          1      Travel_Rarely  Research & Development
# 3      33          0  Travel_Frequently  Research & Development
# 4      27          0      Travel_Rarely  Research & Development
# ...   ...        ...                ...                     ...
# 1465   36          0  Travel_Frequently  Research & Development
# 1466   39          0      Travel_Rarely  Research & Development
# 1467   27          0      Travel_Rarely  Research & Development
# 1468   49          0  Travel_Frequently                   Sales
# 1469   34          0      Travel_Rarely  Research & Development
#
#      EducationField  EnvironmentSatisfaction  Gender  JobInvolvement  \
# 0     Life Sciences                        2  Female               3
# ...

# %%
#pip install sweetviz

# %%
#pip install dtale

# %%
#pip install autoviz

# %%
data_1.corr()
# Out:
#                               Age  Attrition  EnvironmentSatisfaction  \
# Age                      1.000000        NaN                -0.030219
# Attrition                     NaN        NaN                      NaN
# EnvironmentSatisfaction -0.030219        NaN                 1.000000
# JobInvolvement           0.070830        NaN                 0.093255
# JobLevel                 0.500386        NaN                -0.081197
# JobSatisfaction          0.031509        NaN                 0.046915
# MonthlyIncome            0.500602        NaN                -0.089457
# TotalWorkingYears        0.672621        NaN                -0.058569
# WorkLifeBalance         -0.075944        NaN                -0.099402
# YearsAtCompany           0.452909        NaN                 0.031420
# YearsInCurrentRole       0.384303        NaN                 0.006475
# YearsSinceLastPromotion  0.329246        NaN                 0.104580
# ...

# %%
data_nocat = data.drop(cat_cols, axis=1)
